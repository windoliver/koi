# %% [markdown]
# # Golden Query Notebook
# This notebook is used for golden query tests.

# %%
x = 42
print(f'The answer is {x}')
# Out:
# The answer is 42

# %% [raw]
# ---
# title: Golden Test
# ---
